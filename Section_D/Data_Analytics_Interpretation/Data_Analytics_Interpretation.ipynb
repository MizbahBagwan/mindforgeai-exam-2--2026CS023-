# %% [markdown]
# 1. Which department appears strongest in the dataset and why?
#
# ANS:
#
# Computer Engineering is the strongest department because its students have the highest readiness scores and good attendance, assignment, and lab scores.
#
# 2. Which students need immediate academic support and what signals show that?
#
# ANS:
#
# Harshada needs immediate support because of low attendance, fewer diary entries, fewer completed tasks, and low assignment and lab scores.
#
# Divya also needs support because her attendance and scores are lower than most other students.
#
# 3. What is one limitation of this small dataset?
#
# ANS:
#
# The dataset has only 8 students, so it may not represent all students.
#
# 4. What extra columns would make the analysis more useful?
#
# ANS:
#
# Some useful extra columns are:
#
# CGPA
# Mid-semester marks
# Project marks
# Mentor feedback
