# %% [markdown]
# Q.4Control Flow Trace5
# Dry-run the following logic for scores 38, 62, 81, and 94. Write the output band for each score.
#
# if score < 40:
#     band = "Support"
# elif score < 70:
#     band = "Developing"
# elif score < 90:
#     band = "Strong"
# else:
#     band = "Excellent"
#
#
# ANS:
#
# Score 38 → Support
#
# Score 62 → Developing
#
# Score 81 → Strong
#
# Score 94 → Excellent
