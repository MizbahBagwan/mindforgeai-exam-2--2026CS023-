# %% [markdown]
# Q.3 Variables, Memory and Identity
#
# a, b, and c all store the value 25.
# names creates a list with Asha and Riya.
# same_names points to the same list as names.
# Adding "Neha" to same_names also changes names.
# Final list: ["Asha", "Riya", "Neha"].
