# %% [markdown]
# Q.2Write a clean algorithm or pseudocode for a student performance analytics pipeline. It should read tabular data, validate missing values, calculate attendance and task performance signals, classify each student into a performance band, and generate three final insights.
#
# Your pseudocode must include input, process, output, decision conditions, loop structure, and edge cases.
#
# ANS:
#
# START
#
# INPUT student data
#
# FOR each student
#     Check missing values
#     Calculate readiness score
#
#     IF score < 45
#         Support
#     ELSE IF score < 70
#         Developing
#     ELSE IF score < 90
#         Strong
#     ELSE
#         Excellent
#
# END FOR
#
# OUTPUT:
# - Department average
# - Top performer
# - Students needing support
#
# END
# ```
