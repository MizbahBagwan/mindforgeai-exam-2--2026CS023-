# %% [markdown]
# Workspace Architecture Map8
#
# Q.1 Draw and explain the workflow you will use for this exam. Your answer must include VS Code, local Jupyter, Google Colab, GitHub repository, Google Drive submission folder, and the final portal submission. Mention what each tool is responsible for.
#
# ANS:
#
# VS Code: Write and edit Python code.
#
# Local Jupyter: Test and execute the notebook locally.
#
# Google Colab: Run the notebook online and generate outputs
# .
# GitHub Repository: Store the notebook, dataset, README, and screenshots.
#
# Google Drive & Student Portal: Save all files in Google Drive and submit the PDF and required links through the Student Portal
